# %% [markdown]
# # Day 1: Introduction to Python: syntax, variables, data types

# %% [markdown]
# # Syntax

# %% [markdown]
# The language that governs how we write python programming. There are many things that we can write about python like comments, which you can use # sign
# to input your comments. Comments explain what your code is doing, many reasons to write comments: maybe to remember an idea, etc.
# The first thing to learn is how to execute 'Hello World'

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# Another one is indentation, python has a particular way of writing it to follow the python convention

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
greeting ='Hello world'
print(f'{greeting}')
# Out:
# Hello world

# %%
# Code Block

A code block is a group of lines that Python runs together
for i in range(1, 4):
print(i)

# %% [markdown]
# Python Reserve Word
#
# keywords: Special words Python reserves:
# if
# else
# elif
# for
# in # etc Don't use these as variable names
#
#
# # Output
# print('Hello, World!') # This prints a string to the console
#
# f-string
# An f-string (short for formatted string literal) is a way to embed expressions inside string literals in Python. It was introduced in Python 3.6 and makes string formatting more readable and concise.
#
# Syntax: You write an f-string by prefixing the string with the letter f or F and then including variables or expressions inside curly braces{}.

# %%
# OutPut

name = "Alice"
print(f'hello {name}!')

Input

# Input
name - input("Enter Your Name:") # This get input from the user
print("Hello, " + name) # This prints a greeeting with your name entered

# Input
age = int(input("Enter your age: ")) # Get age as an integer
print(f"You are {age} years old!") # Print the age

# %% [markdown]
# # Variable

# %% [markdown]
# A variable is a named container that stores data in your file e.g
#
# Naming Rules:
# - Start with a letter or _ (not a number).
# - Can contain letters, numbers, or_(no spaces or symbols).
# - Case-sensitive (Name # name).
# - Avoid Python keywords (e.g., don't name a variable print).

# %%
name = 'John' # This is s string variable
age = 25 # This is an integer variable
height = 5.7 # This id a float Variable
_is_valid = True # This is also a valid variable name (starts with an underscore)

# %%
# Assignment (=)
x - 10 # Assigns the value 10 to the variable x
y - 5 # Assigns the value 5 to the variable y

# Multiple Assignments
x, y = 10, 5 # Assigns 10 to x and 5 to y in one line

# %%
name = 'ifeanyi'
print(name)
# Out:
# ifeanyi

# %%
name = 'ifeanyi'
age = 21
print(name)
print(age)
# Out:
# ifeanyi
# 21

# %%
name = 'Nelson'
Age = 30

print(f'My name is {name} and Am {age} years old')
# Out:
# My name is Nelson and Am 30 years old

# %% [markdown]
# To embed variables inside another ststament, you use {} coil bracket

# %%
name = 'Nelson'
age = 30
city = 'Lagos'

print(f'My name is {name} and Am {age} years old and I live in {city}')
# Out:
# My name is Nelson and Am 30 years old and I live in Lagos

# %%
name = input('what is your name?')
age = input('what is your age?')

print(f'My name is {name} and my age is {age}')
# Out:
# what is your name? Nelson
# what is your age? 30
# My name is Nelson and my age is 30

# %%
# updating variable: sp this update literally replaces it with the recent name as below

name = 'Nelson'
print(name)
# Out:
# Nelson

# %%
name = 'Nelson'
name = 'Ade'

print(name)
# Out:
# Ade

# %% [markdown]
# # Data types in python
#
# Boolean, string, integer, float, list, tuple, set, dictionary
#
# Each has a way of representing them in python, for eg.

# %% [markdown]
# - Boolean is always True or False starting with capital letter
# eg: value = True
#
# - String data type is anything data that is enclosed by '', "", """
# eg: name = 'Ade'
#
# - Integer data type is a whole number eg, 1, 100, 500
# eg: Age = 25
#
# - Float data type is a decimal number
# eg: height = 2.5, weight 8.7
#
# - List data type is the one that list many items in your variables
# eg: name of family['nelson', 25, 'Ade', 30, height 2.7] - a list datatype must contain this type of enclosed bracket[], and can contain integer, strig, float etc type of datatypes.
#
# - Tuple data type is similar to list but uses this type of bracket()
# eg: Language = ('Igbo, 'Yoruba' 'Hausa")
#
#
# - Set is uses curly {} type of bracket, and every element in it must be unique, for example below:

# %%
fruit = {'mango', 'orange', 'mango', 'orange'}
print(fruit)
# Out:
# {'orange', 'mango'}

# %% [markdown]
# So it won't print mango orange mango orange because uniques iput set it apart
#
# - Dictionary data type makes use of curly bracket just like set but the way elements are mapped out are different. Dictionary has a 'key' and 'value' mapping.
#
# first element = key
# second element = value
#
# And we can add as many elements as possible
# e,g you want to store the information of a person: name: {'Ade', 25, 'Lagos', 1990}

# %% [markdown]
# Variables conversion
#
# formular for conversion
#
# age = 25
#
# int()
# Str()
#
# To convert age 25, which is an interger to string, you have to below

# %%
age = 25

age = str(age)
print(age)
# Out:
# 25

# %% [markdown]
# Now there is no way to differentiate if it's a stringe or integer, that's why you have to use a particular function to print...'type' as below
# function is anything that comes in(). And with this formula, you will understand all other types of data types.

# %%
age = 25

age = str(age)
print(age, type(age))
# Out:
# 25 <class 'str'>

# %%
# eg, again

person = {
    "name": "Ade",
    "age": 25,
    "city": "Lagos",
    "birth_year": 1990,
    "category": "city"
}

print(type(person))
# Out:
# <class 'dict'>

# %% [markdown]
# # Day 2: Control Structures: Loops and Conditionals

# %% [markdown]
# # conditional statement

# %%
# if
age = 10

if age == 10:
    print(f'The age is {age}')
# Out:
# The age is 10

# %%
# else

age = 10

if age == 10:
    print(age)
else:
    print('the age is', age)
# Out:
# 10

# %%
#elif

age = 10

if age == 1:
    print('if statement executed!')
elif age == 10:
    print('elif statement executed!')
# Out:
# elif statement executed!

# %%
# if, else, elif

name = 'Ade'

if name == 'Chike':
    print('The name is Chike')
elif name == 'Obi':
    print('The name is Obi')
elif name == 'Bisi':
    print("The name is Bisi")
else:
    print(name)
# Out:
# Ade

# %%
#Logical operation 

age = 10
height = 2.5

if age == 10 and height == 2.4:
    print('This is correct')

# True and False → False

# %%
# or 
age = 10
height = 2.5

if age == 10 or height == 2.5:
    print('This is corrct')
# Out:
# This is corrct

# %%
# example conditional statement

fruit = 'watermelon'

if fruit is 'pinnaple':
    print('fruit')

else:
    print('This name is correct')
# Out:
# This name is correct
# <>:5: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# <>:5: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# C:\Users\HomePC\AppData\Local\Temp\ipykernel_2944\333514617.py:5: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   if fruit is 'pinnaple':

# %%
fruit = 'watermelon'

if fruit == 'pinnaple':
    print('fruit')
else:
    print('This name is correct')
# Out:
# This name is correct

# %%
names = ["ifeanyi","Nelson","Victory", "Joseph"]

for name in names:
    if name == "Nelson":
        print("Nelson is a Great Has")
    elif name == "ifeanyi":
        print("Ifeanyi is a good man")
    elif name == "Victory":
        print("Victory is great")
    elif name == "Joseph":
        print("Joseph is a Wonderful Man")
# Out:
# Ifeanyi is a good man
# Nelson is a Great Has
# Victory is great
# Joseph is a Wonderful Man

# %% [markdown]
# # Loop:means going over a data type until it exhaustes: while loop, for loop

# %%
name_list =['ifeany','nelson','victory','joseph']

for name in name_list:
    print(name)
# Out:
# ifeany
# nelson
# victory
# joseph

# %%
name = 'nelson'
for word in name:
    print(name)
# Out:
# nelson
# nelson
# nelson
# nelson
# nelson
# nelson

# %%
age = '12'
for number in age:
    print(number)
# Out:
# 1
# 2

# %%
name = 'mira'
for word in name:
    print(name)
# Out:
# mira
# mira
# mira
# mira

# %%
name = 'nicholas'
for word in name:
    print(name)
# Out:
# nicholas
# nicholas
# nicholas
# nicholas
# nicholas
# nicholas
# nicholas
# nicholas

# %%
# while loop is similar to 'for' but must must meet the coondition

# %%
Age = 25

while True:
    print('The age is 25')

# %%
count =10

while co

# %%
# break and continue - this is a keyword use inisde a loop

# %%
names = ['nelson', 'victory', 'joseph', 'ifeanyi']

for name in names:
    if name == 'nelson':
        break
    else:
        print(name)

# %%
names = ['nelson', 'victory', 'joseph', 'ifeanyi']

for name in names:
    if name == 'nelson':
        continue
    else:
        print(name)
# Out:
# victory
# joseph
# ifeanyi

# %%
# while loop uses a condition to start and stop

# %%
while condition:
    print('Add logics here')

# if the condition equates to true, the while loop will always be running
# if the condition equates false, while loop will stop running

# how do we state the condtion

# %%
number = 0

while number < 5:
    print('let this loop be running')
    number = number + 1
# Out:
# let this loop be running
# let this loop be running
# let this loop be running
# let this loop be running
# let this loop be running

# %% [markdown]
# # Day 3: Class, Function and Modules

# %% [markdown]
# # FUNCTION AND MODULES

# %%
# FUNCTION IS writing a reusable code in your python script. We need to define the name of a function using 'def' keyword. After which we need to give a name of the function tha that def is perfoming, and add ().

# %%
def multiplication():
    number = 5
    multi = number * 2
    Print(multi)

# %%
def multiply():
 numb = 5
 multi = numb *2

 print(multi)

multiply():

# %%
def print_names():
    class_names = ['Nelson', 'Ifeanyi']
    for student in class_names:
        print(student)

print_names()
# Out:
# Nelson
# Ifeanyi

# %% [markdown]
# ## function parameter and argument: add an argument or paramater that specifiy

# %%
def add(day,hour):
    ans = day + hour
    print(ans)
add(1,7)
# Out:
# 8

# %%
# types of argument
# 1 positional argument-states that the function youare calling must maintain an exact position

# %%
def substract(day,hour):
    ans = day - hour
    print(ans)
substract(5,2)
# Out:
# 3

# %%
# If you had called 'substract(5,2, 3, 4)' it won't run because it's in 4 positions rather than 2

# %%
## keyword Argument declares a value to our paramenter

# %%
def class_names(name='ADE',age=23):
    print(name)
    print(age)

# %%
class_names()
# Out:
# ADE
# 23

# %%
class_names(name='Bisi',age=20)
# Out:
# Bisi
# 20

# %%
class_names(name ='Ifeanyi')
# Out:
# Ifeanyi
# 23

# %%
class_names(age30)

# %% [markdown]
# ## *args Arguments

# %%
def name(name,age):
    print(name)
    print(age)
# Out:
# Bisi
# 12

# %%
name('Bisi',12)
# Out:
# Bisi
# 12

# %%
def name(*arg):
    for item in arg:
    print(item)

# %%
name('Ade',28,30,30,70,'bis')

# %%
def class_name(lastname,*arg):
    print(lastname)
    print(arg)

# %%
class_name('innocent',12,'lagos','male')
# Out:
# innocent
# (12, 'lagos', 'male')

# %%
# This type, you can call it with many arguments as possible

# %%
def name_details(name,*arg):
    print(name)
    print(arg)

# %%
name_details('Ade', 20, 'lagos', 2.5, 'Ada')
# Out:
# Ade
# (20, 'lagos', 2.5, 'Ada')

# %%
name_details('Obi', 27, 'Edo', 3,'bisi', 'emeka', 898)
# Out:
# Obi
# (27, 'Edo', 3, 'bisi', 'emeka', 898)

# %% [markdown]
# ## Return in functions

# %%
It means we can retrive any value we have in the kayword using return function

# %%
def add(hours, minute):
    ans = hours + minute
    return ans

# %%
ans = add(5,7)

# %%
print(ans)
# Out:
# 12

# %% [markdown]
# ## Scope function: means it will make use of what inside it first before, looking outside

# %%
def add(day,hour):
    ans = day + hour
    print(ans)
add(1,7)
# Out:
# 8

# %%
# types of argument
# 1 positional argument-states that the function youare calling must maintain an exact position

# %%
def substract(day,hour):
    ans = day - hour
    print(ans)
substract(5,2)
# Out:
# 3

# %%
# If you had called 'substract(5,2, 3, 4)' it won't run because it's in 4 positions rather than 2

# %%
## keyword Argument declares a value to our paramenter

# %%
def class_names(name='ADE',age=23):
    print(name)
    print(age)

# %%
class_names()
# Out:
# ADE
# 23

# %%
class_names(name='Bisi',age=20)
# Out:
# Bisi
# 20

# %%
class_names(name ='Ifeanyi')
# Out:
# Ifeanyi
# 23

# %%
class_names(age =30)
# Out:
# ADE
# 30

# %% [markdown]
# ## *args Arguments

# %%
def name(name,age):
    print(name)
    print(age)

# %%
name('Bisi',12)
# Out:
# Bisi
# 12

# %%
def name(*arg):
    for item in arg:
    print(item)

# %%
name('Ade',28,30,30,70,'bis')

# %%
def class_name(lastname,*arg):
    print(lastname)
    print(arg)

# %%
class_name('innocent',12,'lagos','male')
# Out:
# innocent
# (12, 'lagos', 'male')

# %%
# This type, you can call it with many arguments as possible

# %%
def name_details(name,*arg):
    print(name)
    print(arg)

# %%
name_details('Ade', 20, 'lagos', 2.5, 'Ada')
# Out:
# Ade
# (20, 'lagos', 2.5, 'Ada')

# %%
name_details('Obi', 27, 'Edo', 3,'bisi', 'emeka', 898)
# Out:
# Obi
# (27, 'Edo', 3, 'bisi', 'emeka', 898)

# %%
def student_names(name,*arg):
    print(name)
    print(arg)

# %%
student_names('nelson', 'Victory', 25, 30, 'Ayo', 46)
# Out:
# nelson
# ('Victory', 25, 30, 'Ayo', 46)

# %% [markdown]
# ## Return in functions¶

# %%
It means we can retrive any value we have in the kayword using return function

# %%
def add(hours, minute):
    ans = hours + minute
    return ans

# %%
ans = add(5,7)

# %%
print(ans)
# Out:
# 12

# %% [markdown]
# ## Scope function: means it will make use of what inside it first before, looking outside

# %%
def class_name():
    name = 'nelson'

    print(name)

class_name()

# %%
## Global variable

# %%
add = 'st Peter Church'

def address():
    print(add) # it accesses global variable

# %%
address()

# %% [markdown]
# ## Modules

# %%
# Modules is a file containing python script (modules, variables ect)
# Standard module is the one that comes with the python when you installed it
# third party is the one you instaled like jupyter 

# for standard:
# Import math
# Import time
# Import random

# maths:

# %%
import math

sqrt = math.sqrt(81)
print(sqrt)
# Out:
# 9.0

# %%
import time

for num in range (5):
    time.sleep(2)
    print(num)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
import random

random_num = random.randint(1, 10)
print(random_num)
# Out:
# 6

# %%
# The concept is to understand that we can import our own seperate script into the work script using import function

# %% [markdown]
# # Third party module: modules that you install into your system

# %%
# example: 
# pandas
# rumpy

import pandas
import rumpy

# use import function to import them

# %%
# Custom module is the modules that you created (any files that has extenstion(.py)
